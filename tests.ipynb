# %% [markdown]
# # Notebook to test developed functions

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.problems import ZDT3
zdt3 = ZDT3(dimension=30)
zdt3.plot_function()

# %%
from src.problems import CF6
cf6 = CF6(dimension=30)
cf6.plot_function()

# %%
# Create an instance of ev_algorithm.py
from src.ev_algorithm import EA

problem = zdt3
population_size = 100
generations = 100
dimension = 30
mutation_rate = 0.5
neighborhood_size = 20
SIG = 20

ea = EA(problem, population_size, \
                 generations, mutation_rate, \
                    neighborhood_size, SIG)

# %%
ea.run_algorithm()
# Out:
# Generation:  10 Best fitness:  [0.49447894 3.35479303]
# Generation:  20 Best fitness:  [0.38958453 3.71270044]
# Generation:  30 Best fitness:  [0.37249896 3.97691248]
# Generation:  40 Best fitness:  [0.19014115 4.3371794 ]
# Generation:  50 Best fitness:  [0.22732015 3.87180886]
# Generation:  60 Best fitness:  [0.17812827 4.38456287]
# Generation:  70 Best fitness:  [0.17891099 4.16127226]
# Generation:  80 Best fitness:  [0.28530708 3.82954014]
# Generation:  90 Best fitness:  [0.35658538 4.12415292]
# Generation:  100 Best fitness:  [0.47302617 3.300653  ]

# %%
ea.plot_historic()
