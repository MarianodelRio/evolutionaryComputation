# %% [markdown]
# # Notebook to test developed functions

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.problems import ZDT3
zdt3 = ZDT3(dimension=30)
zdt3.plot_function()

# %%
from src.problems import CF6
cf6 = CF6(dimension=30)
cf6.plot_function()

# %%
# Create an instance of ev_algorithm.py
from src.ev_algorithm import EA

problem = zdt3
population_size = 100
generations = 100
dimension = 30
mutation_rate = 0.5
neighborhood_size = 20
SIG = 20
F = 0.5

ea = EA(problem, population_size, \
                 generations, mutation_rate, \
                    neighborhood_size, SIG, F)

# %%
ea.run_algorithm()
# Out:
# Generation:  10 Best fitness:  [0.83959661 2.02096141]
# Generation:  20 Best fitness:  [0.85349284 1.76383669]
# Generation:  30 Best fitness:  [0.85349284 1.76383669]
# Generation:  40 Best fitness:  [0.66392496 1.73812232]
# Generation:  50 Best fitness:  [0.84931309 1.62507279]
# Generation:  60 Best fitness:  [0.84931309 1.62507279]
# Generation:  70 Best fitness:  [0.65688493 1.56639447]
# Generation:  80 Best fitness:  [0.66304052 1.57240084]
# Generation:  90 Best fitness:  [0.64473861 1.46089481]

# %%
ea.export_historic(name='zdt3_test.csv')
